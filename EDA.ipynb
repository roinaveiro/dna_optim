# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # gene_FPKM_200501.csv

# %%
data = data.set_index('Unnamed: 0')
data.head()
# Out:
#             GSM1717005  GSM3392879  SRX1977870  GSM2090494  GSM2388462  \
# Unnamed: 0
# 35317         0.382268    0.099114    0.337159    0.136644    1.258159
# 5062          0.000000    0.000000    0.000000    0.000000    0.000000
# 6600          0.000000    0.000000    0.000000    0.000000    0.000000
# 24321         0.000000    0.000000    0.000000    0.000000    0.000000
# 33068         0.177099    2.673183    0.090059    2.281365    1.590740
#
#             GSM2731794  GSM2520927  SRX3177096  SRX4170900  SRX2771292  ...  \
# Unnamed: 0                                                              ...
# 35317         0.151155    0.083040    0.363878     0.00000    1.764510  ...
# 5062          0.000000    0.000000    0.000000     0.00000    0.000000  ...
# 6600          0.000000    0.000000    0.000000     0.00000    0.000000  ...
# 24321         0.000000    0.000000    0.000000     0.00000    0.000000  ...
# 33068         0.894481   13.338754    1.448938     4.73042    1.726705  ...
#
#             GSM2790181  SRX349077  SRX4803567  SRX4171194  GSM3573039  \
# Unnamed: 0
# 35317              0.0   0.000000    0.256079    0.000000    2.894369
# 5062               0.0   0.000000    0.000000    0.000000    2.186742
# 6600               0.0   0.000000    0.000000    0.000000    0.000000
# 24321              0.0   0.000000    0.000000    0.000000    1.884976
# 33068              0.0   2.281294    1.910024    0.570215    5.162827
#
#             SRX6381818  SRX4170867  SRX7581663  GSM3638267  SRX6382439
# Unnamed: 0
# 35317              0.0    0.205115    0.251151    0.134670         0.0
# 5062               0.0    0.000000    0.000000    0.000000         0.0
# 6600               0.0    0.000000    0.000000    0.000000         0.0
# 24321              0.0    0.000000    0.000000    0.000000         0.0
# 33068              0.0    1.208940    3.306149    0.133564         0.0
#
# [5 rows x 10000 columns]

# %%
data.index.isin(protein_genes)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
rows_in = np.apply_along_axis(lambda x: np.sum(x == 0), 
                                  axis = 1, arr = data) == 0

# %%
data.head()
# Out:
#    Unnamed: 0  GSM1717005  GSM3392879  SRX1977870  GSM2090494  GSM2388462  \
# 0       35317    0.382268    0.099114    0.337159    0.136644    1.258159
# 1        5062    0.000000    0.000000    0.000000    0.000000    0.000000
# 2        6600    0.000000    0.000000    0.000000    0.000000    0.000000
# 3       24321    0.000000    0.000000    0.000000    0.000000    0.000000
# 4       33068    0.177099    2.673183    0.090059    2.281365    1.590740
#
#    GSM2731794  GSM2520927  SRX3177096  SRX4170900  ...  GSM2790181  SRX349077  \
# 0    0.151155    0.083040    0.363878     0.00000  ...         0.0   0.000000
# 1    0.000000    0.000000    0.000000     0.00000  ...         0.0   0.000000
# 2    0.000000    0.000000    0.000000     0.00000  ...         0.0   0.000000
# 3    0.000000    0.000000    0.000000     0.00000  ...         0.0   0.000000
# 4    0.894481   13.338754    1.448938     4.73042  ...         0.0   2.281294
#
#    SRX4803567  SRX4171194  GSM3573039  SRX6381818  SRX4170867  SRX7581663  \
# 0    0.256079    0.000000    2.894369         0.0    0.205115    0.251151
# 1    0.000000    0.000000    2.186742         0.0    0.000000    0.000000
# 2    0.000000    0.000000    0.000000         0.0    0.000000    0.000000
# 3    0.000000    0.000000    1.884976         0.0    0.000000    0.000000
# 4    1.910024    0.570215    5.162827         0.0    1.208940    3.306149
#
#    GSM3638267  SRX6382439
# 0    0.134670         0.0
# 1    0.000000         0.0
# 2    0.000000         0.0
# 3    0.000000         0.0
# 4    0.133564         0.0
#
# [5 rows x 10001 columns]

# %% [markdown]
# 1. Eliminar datos de genes que tienen expresión 0 en algunas condiciones. Si lo que queremos es ver genes que tienen una expresión estable, parece lógico eliminar los genes que no se expresan en algunos experimentos. Se podría mirar cuántos genes quedan si se quitan los que tienen expresión 0 en 1 experimento, o en el 10% de los experimentos, por ejemplo. Había muchos genes que tenían expresión 0 en la mayoría de experimentos (en el summary de la primera base de datos, de los 27420 genes que expresan proteinas, 7528 tienen una mediana de expresión <0.001).

# %%
def remove_low_expression_genes(data, pct_0=0.1):

    ncol_0  = np.round(pct_0 * data.shape[1])
    rows_in = np.apply_along_axis(lambda x: np.sum(x == 0), 
                                  axis = 1, arr = data) < ncol_0
    

    return data.loc[rows_in]

# %%
data_red = remove_low_expression_genes(data, pct_0=0.1)

# %% [markdown]
# 2. Una vez quitados estos genes, se podría re-escalar los datos de expresión de 0 a 100 para cada experimento (reescalar en cada columna del dataset inicial). En realidad, los valores "absolutos" de expresión no nos interesan tanto como saber si un gen es de los más expresados, o está en el 10% de los menos expresados, por ejemplo. Esto en principio podría disminuir la variación, aunque con la conversión a unidades TPM ya estarían normalizados de alguna forma.

# %%
def scale01(data):
    return data.apply(lambda x: (x - x.min())
                      / (x.max() - x.min()), axis = 0 )

# %%
data_red = scale01(data_red)

# %% [markdown]
# 3. Hacer una resumen de los datos de nuevo para ver cómo quedaría la variación, y si se ven genes más "estables".

# %%
def get_statistics(data):

    # Get statistics
    mean_df = data.mean(axis=1)
    median_df = data.median(axis=1)
    std_df = data.std(axis=1)
    cv_df = data.apply(lambda x: np.std(x, ddof=1) / np.mean(x), axis=1)
    summ_df = pd.concat([mean_df, median_df, std_df, cv_df], axis=1)
    summ_df.columns = ["mean", "median", "std", "cv"]
    summ_df.index = data.index

    #print("Writing Data")
    #summ_df.to_csv("data/summmary_statistics.csv")
    return summ_df

# %%
statistics = get_statistics(data_red)
statistics
# Out:
#                 mean    median       std        cv
# Unnamed: 0
# 35570       0.255306  0.273934  0.156278  0.612120
# 1151        0.088086  0.068795  0.082877  0.940856
# 22692       0.212381  0.170142  0.185451  0.873199
# 13060       0.307822  0.319374  0.192556  0.625545
# 18597       0.190088  0.180518  0.139505  0.733900
# ...              ...       ...       ...       ...
# 31884       0.183355  0.184873  0.129358  0.705504
# 13825       0.116759  0.093619  0.105719  0.905449
# 27251       0.109035  0.097984  0.090973  0.834354
# 37017       0.071182  0.056109  0.064362  0.904187
# 22726       0.446554  0.483080  0.200224  0.448375
#
# [1060 rows x 4 columns]

# %%
def get_top_genes(data, pct=0.1):
    nrows_in = int(np.round(data.shape[0] * pct))
    top_genes = data.sort_values("mean", ascending=False)
    return top_genes.iloc[:nrows_in]

# %%
get_top_genes(statistics, pct=0.1)
# Out:
#                 mean    median       std        cv
# Unnamed: 0
# 36241       0.691636  0.779047  0.287419  0.415564
# 18213       0.682141  0.768845  0.252036  0.369478
# 2742        0.608378  0.735138  0.356496  0.585978
# 28966       0.601635  0.716117  0.315639  0.524635
# 19416       0.585354  0.693266  0.309522  0.528777
# ...              ...       ...       ...       ...
# 18870       0.338778  0.374739  0.193421  0.570936
# 23074       0.338139  0.341473  0.233532  0.690639
# 5913        0.337462  0.361994  0.193766  0.574186
# 17726       0.336891  0.357128  0.205740  0.610700
# 20983       0.336862  0.353425  0.189913  0.563772
#
# [106 rows x 4 columns]

# %% [markdown]
# # Ath-r.c5-0.expression.combat.txt
#
# Expression in log2 TPM units. Back to original scale before filtering 0s

# %%
data = pd.read_csv("data/data_atted/original_files/Ath-r.c5-0.expression.combat.txt", sep = "\t")

# %%
data = 2**data

# %%
def remove_low_expression_genes(data, pct_0=0.1, th=0.0, all=False):

    if all:
         rows_in = np.apply_along_axis(lambda x: np.sum(x <= th), 
                                  axis = 1, arr = data) == 0

    else: 
        ncol_0  = np.round(pct_0 * data.shape[1])
        rows_in = np.apply_along_axis(lambda x: np.sum(x <= th), 
                                    axis = 1, arr = data) < ncol_0

    return data.loc[rows_in]

# %%
data
# Out:
#            DRR031752   DRR031753   DRR031754   DRR031755   DRR031756  \
# 10723023    9.239405    9.153985    9.324330    9.826652    7.629032
# 10723027    9.193409    5.083774    6.275803    9.193409    8.999844
# 10723028   33.266542   30.673056   32.046613   32.046613   28.224967
# 10723029   63.219600   95.438535   73.588070   51.482136   45.317614
# 10723033   17.939901   16.241354   19.475656   22.677662   18.093505
# ...              ...         ...         ...         ...         ...
# 844435    149.624229  142.152928  143.698381  130.192272  122.768787
# 844436      9.134337   11.434331    8.099877    8.876556    5.734628
# 844438      1.564824    1.113267    1.242719    1.592397    0.744477
# 844441      5.683186    5.988937    5.912220    2.580946    5.302968
# 844443     30.210957   27.255963   29.768198   35.669028   34.249238
#
#            DRR031757   DRR031758   DRR031760   DRR031761   DRR031762  ...  \
# 10723023    8.092582   51.901344   50.615242   45.471793   43.066674  ...
# 10723027    5.331347   29.946178   30.632687   34.294374   34.939813  ...
# 10723028   30.826517   89.996688  105.983804  126.124086   78.384690  ...
# 10723029   71.839231  441.692952  344.843987  187.754022  250.280139  ...
# 10723033   20.546204   77.935029   72.978521   49.611408   54.530822  ...
# ...              ...         ...         ...         ...         ...  ...
# 844435    137.491631  358.666701  411.514655  398.131166  309.243615  ...
# 844436      5.734628   57.456571   65.118700   65.567092   47.659767  ...
# 844438      1.731593    5.954994   10.173894    7.295465    5.236127  ...
# 844441      8.246032   33.087170   43.640629   19.992680   16.004437  ...
# 844443     28.870016  115.977409  136.333850  132.854198  105.178790  ...
#
#            SRR988012   SRR988013    SRR988015   SRR988016   SRR988017  \
# 10723023   31.043084   14.489139    93.157499   14.489139   17.897672
# 10723027   16.635577    7.845688   100.433726   10.807044    5.196355
# 10723028   61.512171   41.539156   310.360254   46.385436   48.486123
# 10723029  181.849355  128.480001   880.024574  240.451147   29.405212
# 10723033   47.458678   20.287230   112.688775   55.804130   18.683593
# ...              ...         ...          ...         ...         ...
# 844435    175.472361  128.399876  1081.636480  188.758788  230.432437
# 844436     14.654786   10.606671   216.361501   17.438451   14.174245
# 844438      1.332282    0.785781    32.258333    3.865620    3.024088
# 844441      7.651274    4.914348   108.948309    6.613894   14.630427
# 844443     37.650575   18.649952   367.525362   57.265725   75.077047
#
#            SRR988018   SRR988019   SRR988020   SRR988021   SRR988022
# 10723023   13.220456   12.006136   20.103851   12.606536   12.606536
# 10723027   12.392540   10.807044   19.358564    7.152264    5.826785
# 10723028   40.543536   38.337916   44.320431   35.236531   32.462450
# 10723029   80.924240  118.529306  329.949175   18.646074   61.015336
# 10723033   27.223865   19.478356   58.916507   14.204735   35.481621
# ...              ...         ...         ...         ...         ...
# 844435    233.050694  201.453073  192.591470  205.657518  184.119676
# 844436     16.398592   18.508294   30.202582   14.897517   11.237896
# 844438      2.205338    6.359000    4.227779    2.068808    2.345670
# 844441     12.439012   13.790473    9.212547    8.305114    4.739057
# 844443     54.372302   71.933904   75.531158   60.200351   53.553167
#
# [18957 rows x 14741 columns]

# %%
conversion = pd.read_csv("data/gene_id_conversion.txt", delim_whitespace=True )
conversion = conversion.set_index("ENTREZID")
data = data[data.index.isin(conversion.index)]
data.index = conversion.loc[data.index.values, 'TAIR']

# %%
data
# Out:
#             DRR031752   DRR031753   DRR031754   DRR031755   DRR031756  \
# TAIR
# AT1G24095    9.239405    9.153985    9.324330    9.826652    7.629032
# AT4G22758    9.193409    5.083774    6.275803    9.193409    8.999844
# AT3G49142    5.397907    4.066535    7.084667    5.397907    5.019696
# AT1G63295    3.721283    3.015924    4.754851    3.416928    4.964677
# AT4G22305   64.226644   78.951786   67.205155   91.019263   59.561162
# ...               ...         ...         ...         ...         ...
# AT1G80950  149.624229  142.152928  143.698381  130.192272  122.768787
# AT1G80960    9.134337   11.434331    8.099877    8.876556    5.734628
# AT1G80980    1.564824    1.113267    1.242719    1.592397    0.744477
# AT1G64625    5.683186    5.988937    5.912220    2.580946    5.302968
# AT1G77810   30.210957   27.255963   29.768198   35.669028   34.249238
#
#             DRR031757   DRR031758   DRR031760   DRR031761   DRR031762  ...  \
# TAIR                                                                   ...
# AT1G24095    8.092582   51.901344   50.615242   45.471793   43.066674  ...
# AT4G22758    5.331347   29.946178   30.632687   34.294374   34.939813  ...
# AT3G49142    7.826678   23.029321   27.201230   32.198018   21.454375  ...
# AT1G63295    3.215627   34.896247   22.359252   17.684334   19.514844  ...
# AT4G22305   88.358682   69.013180   99.174685   56.996444   23.500182  ...
# ...               ...         ...         ...         ...         ...  ...
# AT1G80950  137.491631  358.666701  411.514655  398.131166  309.243615  ...
# AT1G80960    5.734628   57.456571   65.118700   65.567092   47.659767  ...
# AT1G80980    1.731593    5.954994   10.173894    7.295465    5.236127  ...
# AT1G64625    8.246032   33.087170   43.640629   19.992680   16.004437  ...
# AT1G77810   28.870016  115.977409  136.333850  132.854198  105.178790  ...
#
#             SRR988012   SRR988013    SRR988015   SRR988016   SRR988017  \
# TAIR
# AT1G24095   31.043084   14.489139    93.157499   14.489139   17.897672
# AT4G22758   16.635577    7.845688   100.433726   10.807044    5.196355
# AT3G49142    5.799787    3.800002    68.603011   15.110715   20.593255
# AT1G63295    7.828848   13.760872   104.184728   10.046353   13.760872
# AT4G22305  143.748192   20.173647   255.361992   71.526205   36.758347
# ...               ...         ...          ...         ...         ...
# AT1G80950  175.472361  128.399876  1081.636480  188.758788  230.432437
# AT1G80960   14.654786   10.606671   216.361501   17.438451   14.174245
# AT1G80980    1.332282    0.785781    32.258333    3.865620    3.024088
# AT1G64625    7.651274    4.914348   108.948309    6.613894   14.630427
# AT1G77810   37.650575   18.649952   367.525362   57.265725   75.077047
#
#             SRR988018   SRR988019   SRR988020   SRR988021   SRR988022
# TAIR
# AT1G24095   13.220456   12.006136   20.103851   12.606536   12.606536
# AT4G22758   12.392540   10.807044   19.358564    7.152264    5.826785
# AT3G49142   14.144801   21.151675   12.515986    9.101473   12.065368
# AT1G63295    5.831633    3.284560    8.911078    7.828848    1.344994
# AT4G22305   45.889749   43.204210   46.798812   46.343657   58.684191
# ...               ...         ...         ...         ...         ...
# AT1G80950  233.050694  201.453073  192.591470  205.657518  184.119676
# AT1G80960   16.398592   18.508294   30.202582   14.897517   11.237896
# AT1G80980    2.205338    6.359000    4.227779    2.068808    2.345670
# AT1G64625   12.439012   13.790473    9.212547    8.305114    4.739057
# AT1G77810   54.372302   71.933904   75.531158   60.200351   53.553167
#
# [18673 rows x 14741 columns]

# %%
data_red = remove_low_expression_genes(data, pct_0=0.1, th=0.1, all=True)

# %%
data.shape
# Out:
# (18673, 14741)

# %%
data_red.shape
# Out:
# (16177, 14741)

# %%
data_red = scale01(data_red)

# %%
statistics = get_statistics(data_red)
statistics
# Out:
#               mean    median       std        cv
# 10723023  0.462353  0.462541  0.072358  0.156499
# 10723027  0.448918  0.448529  0.070923  0.157987
# 10723028  0.529903  0.531529  0.060460  0.114095
# 10723029  0.591566  0.606001  0.098777  0.166975
# 10723033  0.500315  0.501156  0.065030  0.129977
# ...            ...       ...       ...       ...
# 844435    0.622036  0.624276  0.055341  0.088967
# 844436    0.472417  0.477188  0.080805  0.171045
# 844438    0.337682  0.327379  0.092421  0.273692
# 844441    0.426548  0.428673  0.079001  0.185211
# 844443    0.539629  0.541610  0.065061  0.120567
#
# [18957 rows x 4 columns]

# %%
get_top_genes(statistics, pct=0.1)
# Out:
#               mean    median       std        cv
# 843029    0.943741  0.966664  0.068835  0.072939
# 28718911  0.942447  0.958676  0.067144  0.071244
# 839871    0.922263  0.943659  0.074827  0.081134
# 818558    0.915098  0.931271  0.072935  0.079702
# 823901    0.905412  0.928084  0.077927  0.086068
# ...            ...       ...       ...       ...
# 836699    0.684828  0.687875  0.056486  0.082482
# 837180    0.684801  0.689866  0.054919  0.080196
# 814670    0.684750  0.691973  0.059822  0.087363
# 824694    0.684744  0.686729  0.057481  0.083946
# 835598    0.684740  0.687149  0.056726  0.082843
#
# [1896 rows x 4 columns]
